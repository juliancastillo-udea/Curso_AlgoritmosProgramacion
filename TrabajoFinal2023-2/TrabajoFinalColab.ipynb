# %% [markdown]
# <p><img alt="UdeA" height="150px" src="https://upload.wikimedia.org/wikipedia/commons/archive/f/fb/20161010213812%21Escudo-UdeA.svg" align="left" hspace="10px" vspace="0px"></p>
# <img alt="CC" height="150px" src="https://upload.wikimedia.org/wikipedia/commons/thumb/b/b9/Ingenier%C3%ADa_Industrial_UdeA.png/1026px-Ingenier%C3%ADa_Industrial_UdeA.png" align="right" hspace="0px" vspace="0px">
# <br><br>
# <p>
# <h1><center><b>Trabajo Final<br>Algoritmia y Programación</b></center></h1>
# <br><br>
# <hr size=10 noshade color="green">
# </p>
# <p>
# <img alt="CC" height="70px" src="https://mirrors.creativecommons.org/presskit/icons/by.xlarge.png" align="left" hspace="0px" vspace="0px">
# <img alt="Attribution" height="70px" src="https://mirrors.creativecommons.org/presskit/icons/nc.xlarge.png" align="left" hspace="0px" vspace="0px">
# <img alt="NC" height="70px" src="https://mirrors.creativecommons.org/presskit/icons/sa.xlarge.png" align="left" hspace="0px" vspace="0px">
# <img alt="SA" height="70px" src="https://creativecommons.org//wp-content/themes/vocabulary-theme/vocabulary/svg/cc/icons/cc-icons.svg#cc-logo" align="left" hspace="0px" vspace="0px">
# </p>
#
# <div align="right">
# <h2> <b> Por: Julián Andrés Castillo G. </b> </h2>
# <a href="mailto:jandres.castillo@udea.edu.co"> ✉ Julian Andres Castillo Grisales </a>
# </div>
#
# <br>
#
# **El presente curso hace parte de la Ingeniería Industrial de la Universidad de Antioquia.**
#
# ---

# %% [markdown]
# ## **Descripción del problema a solucionar**
#
# El programa a continuación genera en una carpeta especificada 1000 archivos de tipo Excel, Word, TXT, CSV, JSON, XML, PowerPoint, HTML y PNG en múltiples carpetas creadas todas de manera aleatoria. El reto si decides aceptarlo es recorrer el árbol de carpetas e identificar los tipos de archivos, crear un nuevo directorio organizado y clasificarlos por tipo (mover los archivos), creando una carpeta llamada Excel para los archivos tipo Excel, una carpeta llamada Word para los archivos tipo Word y así sucesivamente para los demás tipos de archivos. Los archivos en la nueva carpeta deben ser renombrados usando un consecutivo luego de ordenar los archivos por nombre, cada archivo debe comenzar por un numero de tres dígitos, por ejemplo, el primer archivo se nombrará “001-Nombre.extension”. Adicionalmente debes guardar en un Pandas Dataframe el nombre del archivo anterior, nombre del archivo actual, la ruta anterior, la nueva ruta, el tipo de archivo, el tamaño en múltiples unidades de medida por columna usando las siguientes unidades, bit, byte, Kilobyte y Megabyte (crear una columna para cada tipo de unidad de medida). Adicionalmente en una columna detallar la cantidad de vocales que tiene el nombre del documento, en una columna detallar el número de consonantes que tiene el nombre del documento, la fecha de creación, la última fecha de modificación y por último la cantidad de archivos del mismo tipo en la carpeta de su mismo tipo. Este programa debe guardar su procedimiento en un log de eventos (sea tan preciso como pueda) el log debe tener: fecha, hora, minuto, segundo y milisegundo un separador tabular, la instrucción a realizar, y el tiempo que demora en realizar esta operación. El Log debe tener de encabezado, el nombre del usuario que ejecuta el procedimiento, el sistema operativo, la plataforma y todas sus posibles descripciones, al final detallar la cantidad de procedimientos realizados y el tipo de acción, por ejemplo, contar archivos es una acción, mover es una segunda acción, renombrar es una acción etc.

# %% [markdown]
# El entregable debe ser un documento tipo reporte de software en donde se describan las siguientes especificaciones:

# %% [markdown]
# ## **Documento de visión**
#
# Proporciona una descripción general del software, sus objetivos y beneficios. Debe asignar un nombre al proyecto.

# %% [markdown]
# ## **Especificación de requisitos**
#
# Describe los requisitos funcionales y no funcionales del software.

# %% [markdown]
# ## **Plan de proyecto**
#
# Describe las actividades, el cronograma y el presupuesto del proyecto.

# %% [markdown]
# ## **Plan de versionado**
#
# Describe las versiones del software y su avance cada que se realice un procedimiento relevante en días desde el inicio hasta la entrega final.

# %% [markdown]
# ## **Algoritmo**
#
# Una carpeta con todos los archivos y código utilizados en el proyecto.

# %% [markdown]
# ## **Integrantes**
#
# En la carpeta del proyecto debe existir un archivo README.md en donde con Markdown detalle los nombres de los integrantes, programa al cual pertenece, una foto representativa del nombre del proyecto (no es una foto de los integrantes), la licencia con la cual registra el software.

# %% [markdown]
# ## **GitHub**
#
# El líder del equipo debe crear una cuenta en GitHub y cargar los documentos previamente detallados en la entrega (Lo necesario para cargar en GitHub será explicado en clase).

# %% [markdown]
# ## **Entregas**
#
# ### Entrega 1: Para la primera entrega se debe enviar “Documento de visión”, “Especificación de requisitos”, “Plan de proyecto” y “Plan de versionado” --> 5 de octubre.
# ### Entrega 2: Para la segunda entrega (final) se deben enviar los cambios y sugerencias de la entrega 1 más “Algoritmo” y “GitHub”. Por definir

# %%
# !pip install openpyxl
# !pip install tqdm
# !pip install reportlab
# !pip install python-docx
# !pip install python-pptx
# !pip install XlsxWriter
# !pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install Pillow
# Out:
# Requirement already satisfied: openpyxl in /usr/local/lib/python3.10/dist-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.10/dist-packages (from openpyxl) (1.1.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (4.66.1)
# Collecting reportlab
#   Downloading reportlab-4.0.5-py3-none-any.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 11.8 MB/s eta 0:00:00
# Requirement already satisfied: pillow>=9.0.0 in /usr/local/lib/python3.10/dist-packages (from reportlab) (9.4.0)
# Installing collected packages: reportlab
# Successfully installed reportlab-4.0.5
# Collecting python-docx
#   Downloading python-docx-0.8.11.tar.gz (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 19.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: lxml>=2.3.2 in /usr/local/lib/python3.10/dist-packages (from python-docx) (4.9.3)
# Building wheels for collected packages: python-docx
#   Building wheel for python-docx (setup.py) ... done
#   Created wheel for python-docx: filename=python_docx-0.8.11-py3-none-any.whl size=184487 sha256=7d47d99d458da8b4a385abc6ee1112b3e6395d78ef108773535a0bd1e35c46bf
#   Stored in directory: /root/.cache/pip/wheels/80/27/06/837436d4c3bd989b957a91679966f207bfd71d358d63a8194d
# Successfully built python-docx
# Installing collected packages: python-docx
# Successfully installed python-docx-0.8.11
# Collecting python-pptx
#   Downloading python_pptx-0.6.22-py3-none-any.whl (471 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 471.5/471.5 kB 6.7 MB/s eta 0:00:00
# Requirement already satisfied: lxml>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from python-pptx) (4.9.3)
# Requirement already satisfied: Pillow<=9.5.0,>=3.3.2 in /usr/local/lib/python3.10/dist-packages (from python-pptx) (9.4.0)
# Collecting XlsxWriter>=0.5.7 (from python-pptx)
#   Downloading XlsxWriter-3.1.6-py3-none-any.whl (154 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 154.3/154.3 kB 8.7 MB/s eta 0:00:00
# Installing collected packages: XlsxWriter, python-pptx
# Successfully installed XlsxWriter-3.1.6 python-pptx-0.6.22
# Requirement already satisfied: XlsxWriter in /usr/local/lib/python3.10/dist-packages (3.1.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.23.5)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.43.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.10/dist-packages (9.4.0)

# %%
import os
from openpyxl import Workbook
from docx import Document
import random as rnd
import pandas as pd
from PIL import Image, ImageDraw, ImageFont
from reportlab.lib.pagesizes import letter
from reportlab.pdfgen import canvas
import time
import datetime
import warnings
warnings.filterwarnings('ignore')
import logging
import tqdm
from google.colab import files

inicio = time.time()
print('Ingresar la cantidad de archivos a procesar, ingresar solo numeros enteros.')
print('Si ingresa el numero 10, por ejemplo, se crearan 10 archivos de cada uno.')
print('Generando un total de 100 archivos, A continuacion ingresar el numero.')
archivos = int(input('Ingresar la cantidad: '))
hoy = datetime.date.today().strftime('%Y%m%d')
nombre_archivo_log = f"log_{hoy}.log"
logging.basicConfig(filename=nombre_archivo_log, level=logging.INFO,
                    format='%(asctime)s - %(name)s - %(levelname)s - %(message)s')
logging.info("Iniciando el proceso, por CastilloEnterprises (^人^)(^人^)(^人^)")


#Creamos el directorio (carpeta) en donde se crearan los archivos
DirectorioActual = os.getcwd()
print(f'El directorio actual de trabajo es: \n\t--> {DirectorioActual}, \nEsta carpeta contendrá los archivos del trabajo final')
CarpetaNueva = "CarpetaArchivosTrabajoFinal"
os.makedirs(CarpetaNueva, exist_ok=True)
logging.info("Se crea el directorio {}".format(CarpetaNueva))
print(f"'{CarpetaNueva}' La carpeeta ha sido creada.")
# Nombre de la carpeta donde se crearán los archivos
carpeta = os.path.join(DirectorioActual, "CarpetaArchivosTrabajoFinal")
logging.info("La ruta de trabajo será {}".format(carpeta))
RutaNombres = r'https://raw.githubusercontent.com/juliancastillo-udea/Curso_AlgoritmosProgramacion/main/TrabajoFinal/NombresArgentina.csv'
logging.info("Cargando CSV con nombres")
dfNombres = pd.read_csv(RutaNombres, encoding='ISO-8859-1')
Nombres = dfNombres['name'].tolist()
logging.info("Reemplazando nombres y detalles del documento")
for i in tqdm.trange(len(Nombres)):
    if ' ' in Nombres[i]:
        Nombres[i]=Nombres[i].replace(' ', '_')
logging.info("Creacion de archivos")
for i in tqdm.trange(int(archivos), miniters=int(1), ascii=True,desc="Creando Archivos", dynamic_ncols=True):
    # Crear un archivo de Excel usando openpyxl--------------------------------
    logging.info(f"Creacion de archivos-->Excel {i+1}")
    wb = Workbook()
    ws = wb.active
    ws['A1'] = 'Hola soy un numero aleatorio'
    ws['A2'] = rnd.random()
    tempNombre = rnd.choice(Nombres)
    Nombres.remove(tempNombre)
    excel_filename = os.path.join(carpeta, tempNombre+'.xlsx')
    wb.save(excel_filename)

    # Crear un archivo de Word usando python-docx------------------------------
    logging.info(f"Creacion de archivos-->Word {i+1}")
    doc = Document()
    doc.add_paragraph(f"¡Hola! Este es un archivo de Word creado desde Python. \n Soy un numero aleatorio {rnd.random()}")
    tempNombre = rnd.choice(Nombres)
    Nombres.remove(tempNombre)
    word_filename = os.path.join(carpeta, tempNombre+'.docx')
    doc.save(word_filename)

    # Crear un archivo de texto (txt)------------------------------------------
    logging.info(f"Creacion de archivos-->Texto {i+1}")
    texto = f"¡Hola! Este es un archivo de Word creado desde Python. \n Soy un numero aleatorio {rnd.random()}"
    tempNombre = rnd.choice(Nombres)
    Nombres.remove(tempNombre)
    txt_filename = os.path.join(carpeta, tempNombre+'.txt')
    with open(txt_filename, 'w') as txt_file:
        txt_file.write(texto)

    # Crear un archivo CSV-----------------------------------------------------
    logging.info(f"Creacion de archivos-->CSV {i+1}")
    csv_data = f"Nombre,Edad\n{rnd.choice(Nombres)},{rnd.uniform(18,60)}\n"
    csv_data += f"{rnd.choice(Nombres)},{rnd.uniform(18,60)}\n"
    csv_data += f"{rnd.choice(Nombres)},{rnd.uniform(18,60)}\n"
    tempNombre = rnd.choice(Nombres)
    Nombres.remove(tempNombre)
    csv_filename = os.path.join(carpeta, tempNombre+'.csv')
    with open(csv_filename, 'w') as csv_file:
        csv_file.write(csv_data)

    # Crear un archivo JSON----------------------------------------------------
    logging.info(f"Creacion de archivos-->JSON {i+1}")
    import json
    json_data = {"nombre": rnd.choice(Nombres), "edad": rnd.uniform(18,60)}
    tempNombre = rnd.choice(Nombres)
    Nombres.remove(tempNombre)
    json_filename = os.path.join(carpeta, tempNombre+'.json')
    with open(json_filename, 'w') as json_file:
        json.dump(json_data, json_file, indent=4)

    # Crear un archivo XML-----------------------------------------------------
    logging.info(f"Creacion de archivos-->XML {i+1}")
    xml_data = f"""<?xml version="1.0" encoding="UTF-8"?>
    <datos>
        <persona>
            <nombre>{rnd.choice(Nombres)}</nombre>
            <edad>{rnd.uniform(18,60)}</edad>
        </persona>
        <persona>
            <nombre>{rnd.choice(Nombres)}</nombre>
            <edad>{rnd.uniform(18,60)}</edad>
        </persona>
    </datos>
    """
    tempNombre = rnd.choice(Nombres)
    Nombres.remove(tempNombre)
    xml_filename = os.path.join(carpeta, tempNombre+'.xml')
    with open(xml_filename, 'w') as xml_file:
        xml_file.write(xml_data)

    # Crear un archivo de PowerPoint-------------------------------------------
    logging.info(f"Creacion de archivos-->PowerPoint {i+1}")
    from pptx import Presentation
    ppt = Presentation()
    slide = ppt.slides.add_slide(ppt.slide_layouts[0])
    slide.shapes.title.text = f"Presentación creada desde Python,\n Soy un numero aleatorio {rnd.random()}"
    tempNombre = rnd.choice(Nombres)
    Nombres.remove(tempNombre)
    ppt_filename = os.path.join(carpeta, tempNombre+'.pptx')
    ppt.save(ppt_filename)

    # Crear un archivo HTML----------------------------------------------------
    logging.info(f"Creacion de archivos-->HTML {i+1}")
    html_data = """<!DOCTYPE html>
    <html>
    <head>
        <title>Página HTML creada desde Python</title>
    </head>
    <body>
        <h1>Hola desde Python</h1>
        <h1>Hola soy un numero aleatorio {}</h1>
    </body>
    </html>
    """.format(rnd.random())
    tempNombre = rnd.choice(Nombres)
    Nombres.remove(tempNombre)
    html_filename = os.path.join(carpeta, tempNombre+'.html')
    with open(html_filename, 'w') as html_file:
        html_file.write(html_data)

    #Crear una imagen vacía----------------------------------------------------
    logging.info(f"Creacion de archivos-->Imagen PNG {i+1}")
    ancho = 400
    alto = 400
    imagen_vacia = Image.new('RGB', (ancho, alto), 'white')
    texto = f"Hola soy un numero aleatorio\n {rnd.random()}"
    #fuente = ImageFont.truetype("arial.ttf", 20)
    dibujar = ImageDraw.Draw(imagen_vacia)
    bbox = dibujar.textbbox((0,0), texto)
    ancho_texto = bbox[2] - bbox[0]
    alto_texto = bbox[3] - bbox[1]
    x = (ancho - ancho_texto) / 2
    y = (alto - alto_texto) / 2
    dibujar.text((x, y), texto, fill="black")
    tempNombre = rnd.choice(Nombres)
    Nombres.remove(tempNombre)
    imagen = os.path.join(carpeta, tempNombre+'.png')
    imagen_vacia.save(imagen)

    #Archivo PDF---------------------------------------------------------------
    logging.info(f"Creacion de archivos-->PDF {i+1}")
    tempNombre = rnd.choice(Nombres)
    Nombres.remove(tempNombre)
    pdfarchivo = os.path.join(carpeta, tempNombre+'.pdf')
    c = canvas.Canvas(pdfarchivo, pagesize=letter)
    width, height = letter
    texto = f"Hola soy un archivo PDF con un numero aleatorio \n {rnd.random()}"
    c.drawString(width/4 - 15, height/3, texto)  # Ajusta la posición según lo que necesites
    c.save()
logging.info("Proceso Terminado......")
logging.info("Gracias por usar Castillo Enterprises")
logging.shutdown()

fin = time.time()
tiempoejecucion = fin - inicio
minutos = int(tiempoejecucion // 60)
segundos = tiempoejecucion % 60
print(f"El script tomó {minutos} minutos y {segundos:.2f} segundos para ejecutarse.")
# Out:
# Ingresar la cantidad de archivos a procesar, ingresar solo numeros enteros.
# Si ingresa el numero 10, por ejemplo, se crearan 10 archivos de cada uno.
# Generando un total de 100 archivos, A continuacion ingresar el numero.
# Ingresar la cantidad: 100
# El directorio actual de trabajo es:
# 	--> /content,
# Esta carpeta contendrá los archivos del trabajo final
# 'CarpetaArchivosTrabajoFinal' La carpeeta ha sido creada.
# 100%|██████████| 49340/49340 [00:00<00:00, 1552536.91it/s]
# Creando Archivos: 100%|##########| 100/100 [00:09<00:00, 11.02it/s]
# El script tomó 0 minutos y 11.20 segundos para ejecutarse.

# %%
# !zip -r /content/CarpetaArchivosTrabajoFinal.zip /content/CarpetaArchivosTrabajoFinal
# Out:
#   adding: content/CarpetaArchivosTrabajoFinal/ (stored 0%)
#   adding: content/CarpetaArchivosTrabajoFinal/LAKHBIR.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/BERNARDI.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/JULIO_JESUS.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/NOUZHA.html (deflated 39%)
#   adding: content/CarpetaArchivosTrabajoFinal/LEONARDO_RAMON.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/HERACLIO.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/CRISTHIAN.png (deflated 61%)
#   adding: content/CarpetaArchivosTrabajoFinal/ENACHE.png (deflated 60%)
#   adding: content/CarpetaArchivosTrabajoFinal/GORGUI.csv (deflated 4%)
#   adding: content/CarpetaArchivosTrabajoFinal/RAHAL.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/ROMINA_BELEN.png (deflated 61%)
#   adding: content/CarpetaArchivosTrabajoFinal/ARACELI_PILAR.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/TOBIAS.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/AARON_EDUARDO.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/FERNANDO_FRANCISCO.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/ALFREDO_VICENTE.json (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/MANUEL_ADRIAN.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/PILAR_ELVIRA.json (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/LUCINIO.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/SABRINA_ALEJANDRA.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/CONCEPCION_LUCIA.csv (deflated 5%)
#   adding: content/CarpetaArchivosTrabajoFinal/RIGOBERTO.json (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/XIXI.txt (deflated 5%)
#   adding: content/CarpetaArchivosTrabajoFinal/VICTOR_SAUL.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/SONNIA.png (deflated 61%)
#   adding: content/CarpetaArchivosTrabajoFinal/RICARDO_ALEXANDER.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/GEORGIAN_ALEXANDRU.csv (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/VOJTECH.xml (deflated 49%)
#   adding: content/CarpetaArchivosTrabajoFinal/BASILIDES.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/FRANCISCA_LIDIA.txt (deflated 5%)
#   adding: content/CarpetaArchivosTrabajoFinal/ANA_MARIA_ANTONIA.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/MANUEL_ANSELMO.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/YIXIN.json (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/EMILIO_GREGORIO.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/JULIANA_TERESA.json (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/WENWEN.json (deflated 9%)
#   adding: content/CarpetaArchivosTrabajoFinal/RADU_VASILE.json (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/MANUEL_DAMASO.png (deflated 61%)
#   adding: content/CarpetaArchivosTrabajoFinal/LUCAS_ANTONIO.png (deflated 60%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARIA_CARMEN_ANA.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/PAULA_BEATRIZ.csv (deflated 6%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARIA_MARCELA.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/VINOD.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/TATIANA_ELENA.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/ARANCHA_MARIA.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/ALFREDO_AGUSTIN.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/ANNA_KATHARINA.html (deflated 39%)
#   adding: content/CarpetaArchivosTrabajoFinal/AMATH.png (deflated 60%)
#   adding: content/CarpetaArchivosTrabajoFinal/LAMIS.json (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/TIARE.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/AMELIA_MARIA.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/DEIBY.json (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/UNAI.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/IRIDE.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARIA_SEQUERO.csv (deflated 6%)
#   adding: content/CarpetaArchivosTrabajoFinal/ZULMA_BEATRIZ.csv (deflated 4%)
#   adding: content/CarpetaArchivosTrabajoFinal/BINBIN.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/DIEGO_NICOLAS.xml (deflated 50%)
#   adding: content/CarpetaArchivosTrabajoFinal/FAUSTINO_JUAN.png (deflated 60%)
#   adding: content/CarpetaArchivosTrabajoFinal/GLICERIO.csv (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/FERNANDO_GUILLERMO.json (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/ELIO.xml (deflated 50%)
#   adding: content/CarpetaArchivosTrabajoFinal/NINA_MARIA.png (deflated 61%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARIA_SUSANA.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/LANYING.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/XUEFANG.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/WIKTOR.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/SURYA.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/TORE.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/ANCUTA_IOANA.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/ABDERRAHMEN.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/ANTONIO_NICOLAS.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/NANCY_CARMEN.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/DANIEL_LAURENTIU.png (deflated 60%)
#   adding: content/CarpetaArchivosTrabajoFinal/PATRICIA_ELIZABETH.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/SOHEL.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/CARMEN_TRINIDAD.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/ANGEL_FERNANDO.png (deflated 61%)
#   adding: content/CarpetaArchivosTrabajoFinal/JON_KOLDOBIKA.json (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/SUNDUS.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/MIRIAM_ISABEL.csv (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/LIZ_FABIOLA.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/SUMAIRA.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/ANA_MARIA_DOLORES.json (deflated 9%)
#   adding: content/CarpetaArchivosTrabajoFinal/AILEN.json (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/MANUEL_ELEUTERIO.txt (deflated 5%)
#   adding: content/CarpetaArchivosTrabajoFinal/AKHTAR.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/NESTOR_DANIEL.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/ELIAS_JOSUE.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/SOFIJA.json (deflated 9%)
#   adding: content/CarpetaArchivosTrabajoFinal/OMAMA.png (deflated 61%)
#   adding: content/CarpetaArchivosTrabajoFinal/PERFECTA.csv (deflated 6%)
#   adding: content/CarpetaArchivosTrabajoFinal/EUGENIO_ENRIQUE.png (deflated 64%)
#   adding: content/CarpetaArchivosTrabajoFinal/GUSTAVO_ALBERTO.png (deflated 61%)
#   adding: content/CarpetaArchivosTrabajoFinal/GIAN_PIERO.csv (deflated 4%)
#   adding: content/CarpetaArchivosTrabajoFinal/CONSTANTIN_CORNEL.csv (deflated 6%)
#   adding: content/CarpetaArchivosTrabajoFinal/JIA.json (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/JORDI_MIQUEL.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/ADIELA.xml (deflated 49%)
#   adding: content/CarpetaArchivosTrabajoFinal/ALFUSAINEY.csv (deflated 2%)
#   adding: content/CarpetaArchivosTrabajoFinal/JAMES_STEPHEN.json (deflated 9%)
#   adding: content/CarpetaArchivosTrabajoFinal/ALFONSO_RAMON.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/DIANA_GEORGIEVA.png (deflated 60%)
#   adding: content/CarpetaArchivosTrabajoFinal/HOURYA.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/LUCIA_RAMONA.csv (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/RAMON_JOSEP.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/EMILY_NICOLE.json (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/LIBIA.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/EVA_VANESA.csv (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARIA_STELA.json (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/CRISTINA_FRANCISCA.xml (deflated 51%)
#   adding: content/CarpetaArchivosTrabajoFinal/NICOLAE_CIPRIAN.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/JUAN_ISAAC.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/ELVIA.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/JUSTIN_ALEXANDER.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARIA_BRENDA.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/JORGE_FELIX.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/GUILLERMO_MARCOS.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/ROCIO_CRISTINA.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/ROCIO_MARGARITA.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/SALVADOR_DAVID.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/XIAOLING.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/NOUH.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/HAYET.xml (deflated 50%)
#   adding: content/CarpetaArchivosTrabajoFinal/JAVIER_JOSE.json (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/AYTHAMY.json (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/MILAGROS.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/ROSSELLA.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/ABDEL_ILLAH.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARIA_HERMELINA.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/JESUS_MIGUEL.json (deflated 9%)
#   adding: content/CarpetaArchivosTrabajoFinal/ARIEL_FRANCISCO.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/JEIMY.json (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/EDUARD_IONUT.xml (deflated 50%)
#   adding: content/CarpetaArchivosTrabajoFinal/GLORIA_MARLENE.txt (deflated 4%)
#   adding: content/CarpetaArchivosTrabajoFinal/CELESTINA.png (deflated 60%)
#   adding: content/CarpetaArchivosTrabajoFinal/CHRISTIAN_FABIAN.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/GRACE.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/SUSANA_LIDIA.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/CONSTANTIN_DAN.json (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/IRENE_PINO.html (deflated 39%)
#   adding: content/CarpetaArchivosTrabajoFinal/ZAHEER.json (deflated 9%)
#   adding: content/CarpetaArchivosTrabajoFinal/VIRGINIA_CAROLINA.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/ROMAYSSAE.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/EUGENIO_RAMON.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/PILAR_MONTSERRAT.html (deflated 41%)
#   adding: content/CarpetaArchivosTrabajoFinal/IULIAN_DANIEL.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/SARA_CAROLINA.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/NILDA_GRACIELA.csv (deflated 6%)
#   adding: content/CarpetaArchivosTrabajoFinal/CELIA_TERESA.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARIA_MAGALY.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/DAILOS_MANUEL.png (deflated 61%)
#   adding: content/CarpetaArchivosTrabajoFinal/NUTU.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/PAULA_AMPARO.png (deflated 60%)
#   adding: content/CarpetaArchivosTrabajoFinal/SEVERO.json (deflated 9%)
#   adding: content/CarpetaArchivosTrabajoFinal/IGNACIO_RUBEN.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/FRANCISCO_ILDEFONSO.html (deflated 39%)
#   adding: content/CarpetaArchivosTrabajoFinal/ALEJANDRO_CLAUDIO.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/ALFONSO_AGUSTIN.png (deflated 60%)
#   adding: content/CarpetaArchivosTrabajoFinal/ABDUL_WAHAB.xml (deflated 50%)
#   adding: content/CarpetaArchivosTrabajoFinal/BRUNO_FERNANDO.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/XOAN.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/GEORGETA_MARIA.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/DAVID_JOSEP.json (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/CELESTI.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/ANDREU.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/DAVID_EMANUEL.csv (deflated 5%)
#   adding: content/CarpetaArchivosTrabajoFinal/GABRIELA_ESTEFANIA.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/JUAN_ELEUTERIO.xml (deflated 51%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARIA_ANA_ISABEL.xml (deflated 50%)
#   adding: content/CarpetaArchivosTrabajoFinal/JOHN_EDUARD.txt (deflated 6%)
#   adding: content/CarpetaArchivosTrabajoFinal/DANKA.json (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/SORIN_IOAN.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/VALENTINA.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/ZOE.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/CIPRIANO.xml (deflated 48%)
#   adding: content/CarpetaArchivosTrabajoFinal/HASSEN.xml (deflated 51%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARIA_ALEGRIA.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/JULIANA_MARIA.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/SILVIA_ROCIO.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/PATRIA.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/EMILIIA.json (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/BEATRIZ_NIEVES.csv (deflated 6%)
#   adding: content/CarpetaArchivosTrabajoFinal/ANDREA_MARIBEL.xml (deflated 48%)
#   adding: content/CarpetaArchivosTrabajoFinal/SOFIA_DANIELA.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/ABDELFATAH.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/SANDRA_VALERIA.csv (deflated 6%)
#   adding: content/CarpetaArchivosTrabajoFinal/BOWEN.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/GEORGIAN.png (deflated 61%)
#   adding: content/CarpetaArchivosTrabajoFinal/DAOUIA.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/ANGELES_LUISA.csv (deflated 2%)
#   adding: content/CarpetaArchivosTrabajoFinal/SANTIAGO_ABEL.csv (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/DANIEL_PABLO.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/DELIA_ROCIO.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/BYRON_JOSE.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/YANEISI.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/DYLAND.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/ANTONIO_CELSO.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/ALFREDO_ANDRES.xml (deflated 51%)
#   adding: content/CarpetaArchivosTrabajoFinal/COSIMO.png (deflated 61%)
#   adding: content/CarpetaArchivosTrabajoFinal/JOSEFA_RAFAELA.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/KAREN_VANESSA.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/CARLOS_DAVID.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/ANA_MARIA_GABRIELA.png (deflated 61%)
#   adding: content/CarpetaArchivosTrabajoFinal/ALEXANDRA_ANA_MARIA.csv (deflated 6%)
#   adding: content/CarpetaArchivosTrabajoFinal/JESSICA_PATRICIA.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/DAMIAN_LUIS.xml (deflated 50%)
#   adding: content/CarpetaArchivosTrabajoFinal/IUSTIN.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/ROSA_IRENE.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/EMILIA_SOLEDAD.json (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/NOELIA_ELIZABETH.json (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/NATALIA_DANIELA.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/ANGELES_TRINIDAD.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/ADRIAN_IONUT.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/JAMES_ARTHUR.csv (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/EBENEZER.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/RODICA_CRISTINA.xml (deflated 51%)
#   adding: content/CarpetaArchivosTrabajoFinal/VAHRAM.xml (deflated 50%)
#   adding: content/CarpetaArchivosTrabajoFinal/WENXI.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/SUCCESS.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/ADELINE.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/ADELE.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/ELENA_GEMA.png (deflated 61%)
#   adding: content/CarpetaArchivosTrabajoFinal/LUZ_CARMEN.json (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/CATHERINE_LOUISE.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/XUEJIAO.json (deflated 9%)
#   adding: content/CarpetaArchivosTrabajoFinal/VERONICA_PAULA.png (deflated 61%)
#   adding: content/CarpetaArchivosTrabajoFinal/ALAN_WILLIAM.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/CLAUDIA_DOLORES.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/ANDREA_JACQUELINE.xml (deflated 48%)
#   adding: content/CarpetaArchivosTrabajoFinal/CRISPINIANO.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/VASILE_OVIDIU.html (deflated 39%)
#   adding: content/CarpetaArchivosTrabajoFinal/ANTONIO_BIENVENIDO.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/JULIA_PAZ.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/SATWINDER.json (deflated 9%)
#   adding: content/CarpetaArchivosTrabajoFinal/ARTURO_LUIS.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/MOULAY.xml (deflated 51%)
#   adding: content/CarpetaArchivosTrabajoFinal/DAHAB.xml (deflated 51%)
#   adding: content/CarpetaArchivosTrabajoFinal/GALLA.html (deflated 39%)
#   adding: content/CarpetaArchivosTrabajoFinal/AINE.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/ALEXANDRA_CRISTINA.csv (deflated 5%)
#   adding: content/CarpetaArchivosTrabajoFinal/OTHMANE.png (deflated 61%)
#   adding: content/CarpetaArchivosTrabajoFinal/CRISTINA_LORENA.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/ILENIA_CARMEN.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/RAFAEL_MANUEL.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/YAIZA_CANDELARIA.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/CESARIO.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/RUYMAN_JESUS.png (deflated 63%)
#   adding: content/CarpetaArchivosTrabajoFinal/KAMALJIT.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/JOHANNES_WILHELMUS.xml (deflated 51%)
#   adding: content/CarpetaArchivosTrabajoFinal/ALEXANDER_MARTIN.xml (deflated 50%)
#   adding: content/CarpetaArchivosTrabajoFinal/ZHIMIN.csv (deflated 4%)
#   adding: content/CarpetaArchivosTrabajoFinal/ODILO.csv (deflated 6%)
#   adding: content/CarpetaArchivosTrabajoFinal/JAVIER_ISAAC.csv (deflated 4%)
#   adding: content/CarpetaArchivosTrabajoFinal/CONSTANTIN_ANDREI.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/AINARE.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/GALO_EDUARDO.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/BENITO_DANIEL.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/MOSTAPHA.png (deflated 61%)
#   adding: content/CarpetaArchivosTrabajoFinal/CESAR_RAFAEL.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/CRISTIAN_COSMIN.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/ELENA_GABRIELA.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/JUNE.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/MONICA_NIEVES.html (deflated 39%)
#   adding: content/CarpetaArchivosTrabajoFinal/FRANKLIN_VINICIO.json (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/JULIO_EUGENIO.png (deflated 62%)
#   adding: content/CarpetaArchivosTrabajoFinal/ALINA_ANDREEA.png (deflated 60%)
#   adding: content/CarpetaArchivosTrabajoFinal/MOHAMED_AYOUB.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/MAXIMILIANO.json (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARIA_AMOR.csv (deflated 4%)
#   adding: content/CarpetaArchivosTrabajoFinal/NASMA.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/ANDRES_VALENTIN.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/MABROUK.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/WENJUN.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/XINRU.json (deflated 9%)
#   adding: content/CarpetaArchivosTrabajoFinal/RYAN_ALEXANDER.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/SULTANA.csv (deflated 2%)
#   adding: content/CarpetaArchivosTrabajoFinal/JENNYFER.json (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/IULIA_MARIA.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/DAVID_GUSTAVO.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/KAOUTHAR.xml (deflated 49%)
#   adding: content/CarpetaArchivosTrabajoFinal/IANIS_GABRIEL.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/KELLY.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARIO_ENRIQUE.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARIA_EDELMIRA.html (deflated 39%)
#   adding: content/CarpetaArchivosTrabajoFinal/CHRISTIAN_PAUL.xml (deflated 50%)
#   adding: content/CarpetaArchivosTrabajoFinal/HASEEB.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/JHON_BRAYAN.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARIANA_LOREDANA.png (deflated 60%)
#   adding: content/CarpetaArchivosTrabajoFinal/SILVINA_LAURA.png (deflated 61%)
#   adding: content/CarpetaArchivosTrabajoFinal/MIRCEA_VASILE.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/PENELOPE_MARIA.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/ROY_WILLIAM.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/ORLANDO_RAFAEL.json (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/TRINIDAD_ANGELES.json (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/BEATRIZ_MAGDALENA.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/RAMADAN.xml (deflated 51%)
#   adding: content/CarpetaArchivosTrabajoFinal/EFRAIN.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/HILDEGARD_MARIA.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/RUDDY.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/ALEJANDRA_ROCIO.csv (deflated 4%)
#   adding: content/CarpetaArchivosTrabajoFinal/INKO.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/SERXIO.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/ADRIAN_DAN.json (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/CESAR_OMAR.csv (deflated 6%)
#   adding: content/CarpetaArchivosTrabajoFinal/BLANCA_MIRIAM.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/BLANCA_CARLOTA.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/WILSON_PATRICIO.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/NICOLAE_MIHAI.json (deflated 9%)
#   adding: content/CarpetaArchivosTrabajoFinal/PASTORA.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/ARTUR_MANUEL.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/WENDY_ALEXANDRA.json (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/NELLY_CRISTINA.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/NATALIA_IOANA.csv (deflated 5%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARIA_LUISA_VICTORIA.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARIANA_ADRIANA.png (deflated 61%)
#   adding: content/CarpetaArchivosTrabajoFinal/ANGEL_ALFREDO.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/DAMASO_JESUS.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/JOSE_OCTAVIO.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/JONATHAN_JOEL.json (deflated 9%)
#   adding: content/CarpetaArchivosTrabajoFinal/EL_GHAZOUANI.csv (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/CARMEN_YADIRA.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/JOSE_EMETERIO.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/CONCHITA.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/JOHANNES_MARTINUS.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/RODOLFO.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/ELISE.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/HORACIO_JESUS.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/LIENA.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARTA_JUDITH.html (deflated 39%)
#   adding: content/CarpetaArchivosTrabajoFinal/RAQUEL.xml (deflated 50%)
#   adding: content/CarpetaArchivosTrabajoFinal/MEILING.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/JATINDER.xml (deflated 50%)
#   adding: content/CarpetaArchivosTrabajoFinal/ENRIQUE_CRISTOBAL.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/EMERENCIA.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/SILVIA_JESUS.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/EUTILIA.xml (deflated 49%)
#   adding: content/CarpetaArchivosTrabajoFinal/ANDY_JOEL.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARCO_ADRIAN.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/JESICA_CARMEN.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/ADINA_ANDREEA.csv (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/RONALD_ANTONIO.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/ALBERTO_ALEXIS.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/MOHAMMED_EL_AMINE.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/LEONOR.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARIA_MARGOT.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARIA_YADIRA.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/ROSILENE.pdf (deflated 48%)
#   adding: content/CarpetaArchivosTrabajoFinal/ANTONINA.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/CARMEN_BERTA.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/JAVIER.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/DOLORES_EMILIA.txt (deflated 5%)
#   adding: content/CarpetaArchivosTrabajoFinal/YOEL.xml (deflated 49%)
#   adding: content/CarpetaArchivosTrabajoFinal/ANGEL_SERAFIN.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/SAINEY.json (deflated 9%)
#   adding: content/CarpetaArchivosTrabajoFinal/DOLORES_LUISA.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/ROCIO_MONTSERRAT.txt (deflated 5%)
#   adding: content/CarpetaArchivosTrabajoFinal/CAPITOLINA.txt (deflated 5%)
#   adding: content/CarpetaArchivosTrabajoFinal/JAIME_HUMBERTO.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/FRANCISCO_FULGENCIO.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/ATANAS_IVANOV.png (deflated 60%)
#   adding: content/CarpetaArchivosTrabajoFinal/FATIMA_LORENA.csv (deflated 2%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARIA_PUREZA.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/KATHARINA_MARIA.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/KAREN_JULIANA.csv (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/ELOY_FRANCISCO.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/SANTIAGO_RAFAEL.xml (deflated 49%)
#   adding: content/CarpetaArchivosTrabajoFinal/AMANCIA.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/SHALINI.xml (deflated 48%)
#   adding: content/CarpetaArchivosTrabajoFinal/ROXANA_MARIA.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/BUENSUCESO.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/SULEICA.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/FAKHAR.json (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/ISABEL_RAMONA.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/DAOUR.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/IBRAIN.csv (deflated 4%)
#   adding: content/CarpetaArchivosTrabajoFinal/ARMANDINA.xml (deflated 51%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARIA_SALOME.xml (deflated 50%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARYSOL.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/LIDON.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/MAGDALENA_ANGELES.csv (deflated 5%)
#   adding: content/CarpetaArchivosTrabajoFinal/CARLOS_LUIS.html (deflated 39%)
#   adding: content/CarpetaArchivosTrabajoFinal/ALEXANDER_PATRICIO.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/KARLO.xml (deflated 49%)
#   adding: content/CarpetaArchivosTrabajoFinal/GREGORIO_ANDRES.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/TEGADAY.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/SERGIO_ANDRE.csv (deflated 5%)
#   adding: content/CarpetaArchivosTrabajoFinal/LEONCIO_JESUS.json (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/XIAOJUAN.json (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/RALUCA_ALEXANDRA.png (deflated 62%)
#   adding: content/CarpetaArchivosTrabajoFinal/BLANCA_LUZ.csv (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARTA_EVA.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/MOHAMMED_YASSIN.png (deflated 62%)
#   adding: content/CarpetaArchivosTrabajoFinal/ALEXSANDRO.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/ABIBOU.csv (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/MOHAMED_HASSAN.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/GUSTAVO_CARLOS.png (deflated 61%)
#   adding: content/CarpetaArchivosTrabajoFinal/ADELA_ESTHER.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/PRUDENCI.png (deflated 61%)
#   adding: content/CarpetaArchivosTrabajoFinal/JACOBO_MIGUEL.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/AMEN.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/VITALY.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/ADASSA.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/GIXANE.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/MAJDOULINE.json (deflated 9%)
#   adding: content/CarpetaArchivosTrabajoFinal/YOLANDA_SUSANA.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/ILIE_COSMIN.png (deflated 63%)
#   adding: content/CarpetaArchivosTrabajoFinal/JAVIER_OMAR.csv (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/ALCIDES_RAMON.csv (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/STANCA.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/EKHIOTZ.xml (deflated 49%)
#   adding: content/CarpetaArchivosTrabajoFinal/JOANA_ISABEL.png (deflated 61%)
#   adding: content/CarpetaArchivosTrabajoFinal/JESSICA_PINO.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/ABDELKHALIK.png (deflated 62%)
#   adding: content/CarpetaArchivosTrabajoFinal/CARMEN_ALEXANDRA.xml (deflated 50%)
#   adding: content/CarpetaArchivosTrabajoFinal/CRISTINA_CAROLINA.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/ANGEL_BOLIVAR.csv (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/ALZBETA.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/JOSEFA_RAQUEL.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/BIEITO.csv (deflated 6%)
#   adding: content/CarpetaArchivosTrabajoFinal/JACINTO_ANTONIO.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/MERCEDES_TERESA.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/ALFREDO_JESUS.json (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/IHAN.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/GLORIA_TRINIDAD.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/KELTOUMA.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/TATSIANA.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/JOANA_CARMEN.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/GIOVANNA_ELIZABETH.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/BELHAJ.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/BERTHA_ALICIA.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/CAROLINA_ROSA.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/GLORIA_GUADALUPE.json (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/BADRI.json (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/HEBA.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/ZHAO.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/LAURA_JIMENA.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/RAUL_CESAR.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/SAULE.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/CRISTOBAL_EDUARDO.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/HAOYI.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/AZDDIN.csv (deflated 6%)
#   adding: content/CarpetaArchivosTrabajoFinal/JORGE_GUILLERMO.xml (deflated 48%)
#   adding: content/CarpetaArchivosTrabajoFinal/HRANT.csv (deflated 5%)
#   adding: content/CarpetaArchivosTrabajoFinal/RAFAEL_JORGE.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/EMANUEL_JOSE.png (deflated 61%)
#   adding: content/CarpetaArchivosTrabajoFinal/SILVIA_LILIANA.pdf (deflated 48%)
#   adding: content/CarpetaArchivosTrabajoFinal/FRANCISCO_AMADOR.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/VERONICA_PILAR.json (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/EL_MILOUDIA.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/MOHAMED_YASSIR.xml (deflated 51%)
#   adding: content/CarpetaArchivosTrabajoFinal/PATRICK_CHARLES.xml (deflated 50%)
#   adding: content/CarpetaArchivosTrabajoFinal/LUCIAN_ANDREI.csv (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/FERMIN_SANTIAGO.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/LORENZO_NICOLAS.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/MANJINDER.xml (deflated 48%)
#   adding: content/CarpetaArchivosTrabajoFinal/JAVIER_GREGORIO.xml (deflated 50%)
#   adding: content/CarpetaArchivosTrabajoFinal/MAXIMO_DAVID.json (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/VIRGILIU.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/MAURO_ALBERTO.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/RODRIGO_PEDRO.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/PAULICA.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/AIDA_CARMEN.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/SOLE.csv (deflated 4%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARC_FRANCESC.xml (deflated 50%)
#   adding: content/CarpetaArchivosTrabajoFinal/AQUILINA.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/TERJE.png (deflated 61%)
#   adding: content/CarpetaArchivosTrabajoFinal/CHRISTIAN_JOSUE.csv (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/CHRISTIAN_DANIEL.json (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/ILDA_MARIA.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/REMBERTO.pdf (deflated 48%)
#   adding: content/CarpetaArchivosTrabajoFinal/ZEIAN.xml (deflated 49%)
#   adding: content/CarpetaArchivosTrabajoFinal/TITEL.xml (deflated 50%)
#   adding: content/CarpetaArchivosTrabajoFinal/LEONARDO_AUGUSTO.xml (deflated 49%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARIA_ERIKA.csv (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/MAI.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/HACENE.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/WALTER_ALFREDO.html (deflated 39%)
#   adding: content/CarpetaArchivosTrabajoFinal/NELLY_BEATRIZ.xml (deflated 49%)
#   adding: content/CarpetaArchivosTrabajoFinal/NELLY_RAQUEL.xml (deflated 48%)
#   adding: content/CarpetaArchivosTrabajoFinal/DAVID_STEVEN.csv (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/AMARJIT.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARIA_CARMEN_ELISA.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARIO_JOSUE.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/SOLMIRA.html (deflated 39%)
#   adding: content/CarpetaArchivosTrabajoFinal/LOREDANA_MARIANA.png (deflated 61%)
#   adding: content/CarpetaArchivosTrabajoFinal/ALEJANDRO_LUIS.csv (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/VICENTE_EUGENIO.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/ADERITO.xml (deflated 49%)
#   adding: content/CarpetaArchivosTrabajoFinal/DONACIANO.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/GUILLERMO_ANDRES.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/IBTISAM.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/ORLANDO_MIGUEL.pdf (deflated 48%)
#   adding: content/CarpetaArchivosTrabajoFinal/GHEORGHE_ALEXANDRU.csv (deflated 5%)
#   adding: content/CarpetaArchivosTrabajoFinal/ALINA_DIANA.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/JUAN_CARLOS.csv (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/HEINZ_GUNTER.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/MIRYAM.xml (deflated 50%)
#   adding: content/CarpetaArchivosTrabajoFinal/SERGIO_MARIA.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/YORDANA.png (deflated 62%)
#   adding: content/CarpetaArchivosTrabajoFinal/JULIO_JORGE.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/ZULFIYA.html (deflated 39%)
#   adding: content/CarpetaArchivosTrabajoFinal/AREEBA.csv (deflated 5%)
#   adding: content/CarpetaArchivosTrabajoFinal/LIDIA_EUGENIA.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/MICHAEL_DOUGLAS.png (deflated 60%)
#   adding: content/CarpetaArchivosTrabajoFinal/ISRAR.png (deflated 61%)
#   adding: content/CarpetaArchivosTrabajoFinal/JOSE_SAUL.json (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/JEAN_ROBERT.json (deflated 12%)
#   adding: content/CarpetaArchivosTrabajoFinal/DORIN_CONSTANTIN.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/PEDRO_ALBERTO.xml (deflated 52%)
#   adding: content/CarpetaArchivosTrabajoFinal/NURIA_LUISA.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/ANGEL_JUSTO.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/DANIEL_PATRICK.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/JACINTO_RAMON.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/ANA_JESICA.png (deflated 61%)
#   adding: content/CarpetaArchivosTrabajoFinal/HRISTO_GEORGIEV.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/TRACEY_ANNE.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/MAYRA_MERCEDES.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/CARMEN_MICAELA.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/GERMAN_PATRICIO.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/KULWANT.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/HOSAM.csv (deflated 6%)
#   adding: content/CarpetaArchivosTrabajoFinal/RODRIGO_ALEXANDER.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/LIDIA_TERESA.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/ISIDORA.xml (deflated 50%)
#   adding: content/CarpetaArchivosTrabajoFinal/FEDERICO_EMILIO.json (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/ELENA_ENCARNACION.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/PIERRE_ANTOINE.png (deflated 61%)
#   adding: content/CarpetaArchivosTrabajoFinal/LAIS.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/MAIER.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/GHEORGHE_VASILE.json (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/QUIRINO.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/LOREDANA_FLORINA.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/NARCISO.json (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/LAZARO_ALBERTO.txt (deflated 5%)
#   adding: content/CarpetaArchivosTrabajoFinal/KATHRYN_LOUISE.xml (deflated 50%)
#   adding: content/CarpetaArchivosTrabajoFinal/CYNTHIA_LORENA.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/IVANOV.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/BERTINO.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/ABDELKADIR.xml (deflated 49%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARIA_PAULA.csv (deflated 5%)
#   adding: content/CarpetaArchivosTrabajoFinal/LEONARDO_FRANCISCO.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/OSCAR_MIGUEL.html (deflated 39%)
#   adding: content/CarpetaArchivosTrabajoFinal/EZEQUIELA.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/LYAZID.json (deflated 9%)
#   adding: content/CarpetaArchivosTrabajoFinal/DIMKA.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/HEITOR.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/FAUSTA.txt (deflated 5%)
#   adding: content/CarpetaArchivosTrabajoFinal/DEBORA.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/NECULAE.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/VICTORIA_LOUISE.csv (deflated 5%)
#   adding: content/CarpetaArchivosTrabajoFinal/FRANCISCA_JUANA.xml (deflated 51%)
#   adding: content/CarpetaArchivosTrabajoFinal/LISARD.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/ASMAT.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/NEIL.xlsx (deflated 12%)
#   adding: content/CarpetaArchivosTrabajoFinal/RAQUEL_GLORIA.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/BENITO_ALEJANDRO.xml (deflated 50%)
#   adding: content/CarpetaArchivosTrabajoFinal/MELISSA_CAROLINA.xml (deflated 51%)
#   adding: content/CarpetaArchivosTrabajoFinal/FEDERICO_TOMAS.png (deflated 61%)
#   adding: content/CarpetaArchivosTrabajoFinal/EDGARDO.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/CLARA_MARIA.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/CLEMENTINA_MARIA.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/FAUSTINO_JAVIER.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/MIRO.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/HONORINA.png (deflated 62%)
#   adding: content/CarpetaArchivosTrabajoFinal/PAU_ALBERT.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/VICENT_LLUIS.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARIA_ILUMINADA.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARIA_SEVERINA.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/ZHENGHAO.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/BRIAN.csv (deflated 5%)
#   adding: content/CarpetaArchivosTrabajoFinal/ORSON.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/MINATA.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/YU.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/ANGELE.json (deflated 9%)
#   adding: content/CarpetaArchivosTrabajoFinal/SAUL_FRANCISCO.csv (deflated 2%)
#   adding: content/CarpetaArchivosTrabajoFinal/ERIC_NICOLAS.html (deflated 39%)
#   adding: content/CarpetaArchivosTrabajoFinal/ALVARO_ANTONIO.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/VITALIE.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/ELIZABETH_MARGARET.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/CARMEN_JUANA.png (deflated 62%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARIA_AFRICA.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/PETRA_DOLORES.json (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/RIANA.png (deflated 61%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARCELA_ELIZABETH.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/LEONARDO_DAMIAN.json (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/YAILIN.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/LEIXURI.xml (deflated 49%)
#   adding: content/CarpetaArchivosTrabajoFinal/BERNARDO_GABRIEL.csv (deflated 4%)
#   adding: content/CarpetaArchivosTrabajoFinal/ESTHER_ANTONIA.png (deflated 61%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARIA_BUEYO.xml (deflated 49%)
#   adding: content/CarpetaArchivosTrabajoFinal/ALBERTO_ANTONIO.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/EUGENIA_CARMEN.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/JHON_MARIO.png (deflated 61%)
#   adding: content/CarpetaArchivosTrabajoFinal/RAUL_MARCOS.xml (deflated 51%)
#   adding: content/CarpetaArchivosTrabajoFinal/SANDRA_MARITZA.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/PALWINDER.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/XUE.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/MENGJIE.csv (deflated 5%)
#   adding: content/CarpetaArchivosTrabajoFinal/FRANCISCO_LAZARO.csv (deflated 6%)
#   adding: content/CarpetaArchivosTrabajoFinal/CECILIA_NOEMI.png (deflated 62%)
#   adding: content/CarpetaArchivosTrabajoFinal/IONEL_CATALIN.xml (deflated 48%)
#   adding: content/CarpetaArchivosTrabajoFinal/ELENA_NIEVES.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/WILLIAM_JAVIER.png (deflated 61%)
#   adding: content/CarpetaArchivosTrabajoFinal/MOSTAFA.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/ALEXIS_DANIEL.csv (deflated 5%)
#   adding: content/CarpetaArchivosTrabajoFinal/SALVADOR_JOSE.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/WAIL.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/YONAS.xml (deflated 51%)
#   adding: content/CarpetaArchivosTrabajoFinal/TEREZINHA.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/KATIA.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/PATRICIO_MARCELO.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/LEOPOLDINA.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/ISIS_MARIA.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/JULIAN_JUAN.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/ALEXANDRA_ESTEFANIA.html (deflated 39%)
#   adding: content/CarpetaArchivosTrabajoFinal/MERCEDES_ANGELES.csv (deflated 6%)
#   adding: content/CarpetaArchivosTrabajoFinal/GENADIO.xml (deflated 50%)
#   adding: content/CarpetaArchivosTrabajoFinal/KARIN.csv (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/ROSE_MARIE.png (deflated 61%)
#   adding: content/CarpetaArchivosTrabajoFinal/ADRIAN_MATEO.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/ISHTAR.html (deflated 39%)
# ...
#   adding: content/CarpetaArchivosTrabajoFinal/CHLOE_MARIE.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/LUIS_CARMELO.json (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/OINATZ.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/JOAN_BATISTE.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/ALEXANDRU_DAVID.csv (deflated 6%)
#   adding: content/CarpetaArchivosTrabajoFinal/WARDIA.html (deflated 39%)
#   adding: content/CarpetaArchivosTrabajoFinal/YOLANDA_SOLEDAD.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/CLARA_CARMEN.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/RAJWINDER.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/JHON_JAIME.xml (deflated 48%)
#   adding: content/CarpetaArchivosTrabajoFinal/JOAN_ALBERT.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/NATALIA_ESTHER.csv (deflated 9%)
#   adding: content/CarpetaArchivosTrabajoFinal/OSCAR_GREGORIO.csv (deflated 4%)
#   adding: content/CarpetaArchivosTrabajoFinal/REBEKKA.json (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/MANUEL_PIO.csv (deflated 6%)
#   adding: content/CarpetaArchivosTrabajoFinal/LUCIA_ROSA.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/DOMINGO_ALEXIS.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/JESUS_DAVID.png (deflated 62%)
#   adding: content/CarpetaArchivosTrabajoFinal/MATILDE_AMPARO.png (deflated 61%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARIA_DEMETRIA.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/ZEINABOU.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/KASSIM.txt (deflated 6%)
#   adding: content/CarpetaArchivosTrabajoFinal/TERESA_BEATRIZ.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/BITTOR.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/ESTEBAN_MAURICIO.png (deflated 61%)
#   adding: content/CarpetaArchivosTrabajoFinal/KEVIN_FRANCIS.png (deflated 61%)
#   adding: content/CarpetaArchivosTrabajoFinal/CONCEPCION_GLORIA.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/MATHEO.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/ICAR.json (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/MATILDA.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/JORGE_EMILIANO.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/MIRIAM_ESTER.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/IVONA.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARIA_CARMEN_MAR.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/LEWIS.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/GASTON_NICOLAS.png (deflated 61%)
#   adding: content/CarpetaArchivosTrabajoFinal/SANDRA_PIEDAD.png (deflated 61%)
#   adding: content/CarpetaArchivosTrabajoFinal/ANDREA_ESTHER.xml (deflated 49%)
#   adding: content/CarpetaArchivosTrabajoFinal/IRON.png (deflated 61%)
#   adding: content/CarpetaArchivosTrabajoFinal/NURIA_ASUNCION.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/VICENTE_ALEJANDRO.png (deflated 62%)
#   adding: content/CarpetaArchivosTrabajoFinal/RAUL_ERNESTO.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARIA_FATIMA.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/AMAL.csv (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/ULPIANA.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/GLORIA_ANGELICA.png (deflated 61%)
#   adding: content/CarpetaArchivosTrabajoFinal/BIANCA_SOFIA.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/JMIAA.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/ELISABETA_MARIA.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/ORIOL.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/ILIYA.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/GURAM.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/ANDREW_ALEXANDER.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/ADRIANA_ROSARIO.png (deflated 61%)
#   adding: content/CarpetaArchivosTrabajoFinal/GAUMET.json (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/CESALTINA.txt (deflated 4%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARLIN.csv (deflated 4%)
#   adding: content/CarpetaArchivosTrabajoFinal/BELLA_JOSEFA.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/ANGELICA_LUCIA.xml (deflated 50%)
#   adding: content/CarpetaArchivosTrabajoFinal/AUREA_ISABEL.png (deflated 62%)
#   adding: content/CarpetaArchivosTrabajoFinal/ERIKA_LIZETH.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/NORMA_MARIA.xml (deflated 49%)
#   adding: content/CarpetaArchivosTrabajoFinal/EWELINA_ANNA.json (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/NAIKARI.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/JUDITH_ANN.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/RUTH_ROCIO.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/SONIA.png (deflated 61%)
#   adding: content/CarpetaArchivosTrabajoFinal/NESTOR_ADRIAN.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARGARET_JEAN.json (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/ZUNILDA.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/ANGEL_BENIGNO.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/ASHFAQ.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/CARMELO_EDUARDO.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/MODIBO.html (deflated 39%)
#   adding: content/CarpetaArchivosTrabajoFinal/ELIZABETH_CARMEN.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/MAREK_STANISLAW.json (deflated 9%)
#   adding: content/CarpetaArchivosTrabajoFinal/FACUNDO_JOSE.csv (deflated 6%)
#   adding: content/CarpetaArchivosTrabajoFinal/IZABEL_CRISTINA.xml (deflated 50%)
#   adding: content/CarpetaArchivosTrabajoFinal/ABBASS.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/VERANIA.csv (deflated 6%)
#   adding: content/CarpetaArchivosTrabajoFinal/SANTOS.json (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/HIPOLITO_JOSE.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARC_DAVID.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/ROSA_NARCISA.csv (deflated 6%)
#   adding: content/CarpetaArchivosTrabajoFinal/ANNE_MARIE.xml (deflated 49%)
#   adding: content/CarpetaArchivosTrabajoFinal/LUDOVICA.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/CECILIO_MIGUEL.xml (deflated 50%)
#   adding: content/CarpetaArchivosTrabajoFinal/CLAUDIA_ESPERANZA.png (deflated 60%)
#   adding: content/CarpetaArchivosTrabajoFinal/LUCIA_JUANA.json (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/SERGIO_ALEXIS.png (deflated 61%)
#   adding: content/CarpetaArchivosTrabajoFinal/JOSUE_SEBASTIAN.png (deflated 59%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARIA_MERY.json (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARIA_YLENIA.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/GRAZINA.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARIA_CELERINA.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/YOUSSOUPH.json (deflated 10%)
#   adding: content/CarpetaArchivosTrabajoFinal/YUCHEN.csv (deflated 4%)
#   adding: content/CarpetaArchivosTrabajoFinal/ANGEL_MARCOS.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/KELLY_VANESSA.json (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/NEIL_JOHN.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/ASAHEL.png (deflated 62%)
#   adding: content/CarpetaArchivosTrabajoFinal/ROSA_NURIA.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARIUS_OVIDIU.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/JOSE_VENANCIO.xml (deflated 49%)
#   adding: content/CarpetaArchivosTrabajoFinal/ABDEL_HAFID.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/JOSE_FERNANDO.xml (deflated 51%)
#   adding: content/CarpetaArchivosTrabajoFinal/RAUL_SALVADOR.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/ILMA.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/ANA_MELANIA.csv (deflated 5%)
#   adding: content/CarpetaArchivosTrabajoFinal/VICTOR_HUGO.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/DENIS_STEFAN.json (deflated 9%)
#   adding: content/CarpetaArchivosTrabajoFinal/JUNE_ANN.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/WINFRIED.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/JAIME_ALEXANDER.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/LUISA_FERNANDA.xml (deflated 50%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARIA_BALTASARA.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/CELMIRA.html (deflated 39%)
#   adding: content/CarpetaArchivosTrabajoFinal/ARLETTE.json (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/KHADDOUJA.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/ALEJANDRO_FELIPE.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/LORENZ.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/KIOWA.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/NIKOLAOS.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/SERGIO_DIEGO.csv (deflated 6%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARBELIS.xml (deflated 50%)
#   adding: content/CarpetaArchivosTrabajoFinal/MIGUEL_FABIAN.html (deflated 39%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARIA_ENCARNA.csv (deflated 5%)
#   adding: content/CarpetaArchivosTrabajoFinal/ROSA_RAMONA.html (deflated 39%)
#   adding: content/CarpetaArchivosTrabajoFinal/ANDREA_MARIA.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/ANGEL_MODESTO.csv (deflated 6%)
#   adding: content/CarpetaArchivosTrabajoFinal/LUCY_ANNE.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/NASRINE.png (deflated 61%)
#   adding: content/CarpetaArchivosTrabajoFinal/NURI.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/HARRIET.xml (deflated 51%)
#   adding: content/CarpetaArchivosTrabajoFinal/MONICA_MARIA.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARTIN_ANGEL.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/RAUL_IVAN.xml (deflated 50%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARIA_JOLANTA.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/WILMER_ANTONIO.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/CHRISTIAN_FABRICIO.json (deflated 9%)
#   adding: content/CarpetaArchivosTrabajoFinal/BADREDIN.json (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARTA_SOFIA.png (deflated 61%)
#   adding: content/CarpetaArchivosTrabajoFinal/ELENA_BEATRICE.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/NANCY_STELLA.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/ENRIQUE_GUILLERMO.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/RAFAEL_VALENTIN.png (deflated 63%)
#   adding: content/CarpetaArchivosTrabajoFinal/TIGUIDA.json (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/WISAM.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/ERHIMO.csv (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/EJAZ.html (deflated 39%)
#   adding: content/CarpetaArchivosTrabajoFinal/YESSICA_PINO.xml (deflated 48%)
#   adding: content/CarpetaArchivosTrabajoFinal/HENRY_MARCELO.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/ALBERTO_CRISTOBAL.json (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/REIKO.html (deflated 41%)
#   adding: content/CarpetaArchivosTrabajoFinal/ANTONIA_PETRA.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/FELIX_ALBERTO.xml (deflated 51%)
#   adding: content/CarpetaArchivosTrabajoFinal/CRISTEA.csv (deflated 5%)
#   adding: content/CarpetaArchivosTrabajoFinal/ION_GHEORGHE.png (deflated 61%)
#   adding: content/CarpetaArchivosTrabajoFinal/IONELA_RAMONA.json (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/JOSE_WILSON.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARIA_NORA.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/FRANCISCO_JULIO.html (deflated 39%)
#   adding: content/CarpetaArchivosTrabajoFinal/SABRINA_MARIA.csv (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/NAIRA.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/URAITZ.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/ANTIMO.pdf (deflated 48%)
#   adding: content/CarpetaArchivosTrabajoFinal/SIDNEY.json (deflated 9%)
#   adding: content/CarpetaArchivosTrabajoFinal/CRISTIAN_NICOLAS.xml (deflated 50%)
#   adding: content/CarpetaArchivosTrabajoFinal/DEMI.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/OUIAM.xml (deflated 48%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARY_LUZ.xml (deflated 49%)
#   adding: content/CarpetaArchivosTrabajoFinal/CLAUDIU_MARIUS.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/ADAMO.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/JUAN_FIDEL.png (deflated 63%)
#   adding: content/CarpetaArchivosTrabajoFinal/YANIS.json (deflated 9%)
#   adding: content/CarpetaArchivosTrabajoFinal/CARLA_NEREA.json (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/TINKA.json (deflated 8%)
#   adding: content/CarpetaArchivosTrabajoFinal/YEDRA.csv (deflated 5%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARIA_TEBA.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/BOUSSO.xml (deflated 51%)
#   adding: content/CarpetaArchivosTrabajoFinal/DIEGO_CARMELO.html (deflated 39%)
#   adding: content/CarpetaArchivosTrabajoFinal/BRAIS.xml (deflated 50%)
#   adding: content/CarpetaArchivosTrabajoFinal/DARREN_LEE.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/HELLE.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/OUAFILA.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/ABU.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/ANTONIA_VICTORIA.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/JULIA_SARA.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/SHAHZAD.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/ROMINA_NATALIA.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/DOMINGOS.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/LUMINITA_ELENA.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/SAMAI.png (deflated 61%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARIA_CUEVA_SANTA.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/DAVID_ERNESTO.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/IRINEO.csv (deflated 6%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARCOS_ANTONIO.xml (deflated 50%)
#   adding: content/CarpetaArchivosTrabajoFinal/BOUZID.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/SERGIO_FELIPE.txt (deflated 3%)
#   adding: content/CarpetaArchivosTrabajoFinal/SORALLA.pptx (deflated 21%)
#   adding: content/CarpetaArchivosTrabajoFinal/XU.pdf (deflated 47%)
#   adding: content/CarpetaArchivosTrabajoFinal/DANY.csv (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/DARWIN_JOSE.csv (deflated 6%)
#   adding: content/CarpetaArchivosTrabajoFinal/ALICIA_ROSARIO.docx (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/MARTIN_PETER.html (deflated 40%)
#   adding: content/CarpetaArchivosTrabajoFinal/ENRIQUE_IVAN.xml (deflated 49%)
#   adding: content/CarpetaArchivosTrabajoFinal/VENTSISLAV.json (deflated 7%)
#   adding: content/CarpetaArchivosTrabajoFinal/DAVID_HUMBERTO.xlsx (deflated 11%)
#   adding: content/CarpetaArchivosTrabajoFinal/DANIELA_PAULA.json (deflated 8%)

# %%
files.download('/content/CarpetaArchivosTrabajoFinal.zip')
print('Archivos Descargados, favor revisar la carpeta de descargas')
